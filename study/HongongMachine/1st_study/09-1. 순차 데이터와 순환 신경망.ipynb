# %% [markdown]
# #Chapter 09. 텍스트를 위한 인공 신경망
# ##순차 데이터와 순환 신경망
# ###순차 데이터(sequential data)
# **시계열 데이터(time series data) 피드포워드 신경망(feedforward neural network)**
# ###순환 신경망(recurrent neural network)
# **타임스탭(timestep) 셀(cell) 은닉 상태(hidden state)**
# ###셀의 가중치와 입출력
